# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC, LinearRegression, RidgeCV

train = pd.read_csv('house-prices-advanced-regression-techniques\\train.csv', usecols=[1, 17, 18, 19, 43, 44, 46, 49, 50, 61, 70, 77, 80])
test  = pd.read_csv('house-prices-advanced-regression-techniques\\test.csv', usecols=[1, 17, 18, 19, 43, 44, 46, 49, 50, 61, 70, 77])

# %%
#scatter plot grlivarea/saleprice
var = 'GrLivArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %%
train = train.drop(train[(train['GrLivArea']>3000) & (train['SalePrice']<300000)].index)

# %%
corrt = train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrt, vmax=.8, square=True);

# %%
sns.distplot(df_train['SalePrice'], fit=norm);
fig = plt.figure()

# %%
train['SalePrice'] = np.log(train['SalePrice'])

# %%
sns.distplot(df_train['SalePrice'], fit=norm);
fig = plt.figure()

# %%
kfolds = KFold(n_splits=10, shuffle=True, random_state=420)

#Root mean squared logarithmic error
def rmsle_cv(model):
    kf = KFold(n_splits=10, shuffle=True, random_state=420).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
X_train, y_train = train.loc[:, train.columns != 'SalePrice'], np.log(train['SalePrice'])

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)
ridge = make_pipeline(RobustScaler(), RidgeCV(cv=kfolds))
rf=RandomForestRegressor()
lr=LinearRegression()
tree=DecisionTreeRegressor(random_state=1,max_depth=4)

# %%
ridge_score = rmsle_cv(ridge)
print("Ridge: ",ridge_score.mean(),ridge_score.std())

lasso_score = rmsle_cv(lasso)
print("Lasso: ",lasso_score.mean(), lasso_score.std())

elasticnet_score = rmsle_cv(ENet)
print("ENet: ",elasticnet_score.mean(), elasticnet_score.std())

KRR_score = rmsle_cv(KRR)
print("KRR: ",KRR_score.mean(), KRR_score.std())

GBoost_score = rmsle_cv(GBoost)
print("GBoost: ",GBoost_score.mean(), GBoost_score.std())

rf_score = rmse_cv(rf)
print("Random Forest: ",rf_score.mean(), rf_score.std())

lr_score = rmse_cv(lr)
print("Linear Regression: ",lr_score.mean(), lr_score.std())

tree_score = rmse_cv(tree)
print("Decision Tree: ",tree_score.mean(), tree_score.std())
# Out:
# Ridge:  0.10024953713959457 0.012492400529108463
# Lasso:  0.1002605140385068 0.01296444583456682
# ENet:  0.10025609019453967 0.012951795861276587
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# C:\Users\btam\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:167: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "
# KRR:  0.19173786153966516 0.11559061380968703

# %%
lasso_model = lasso.fit(X_train,y_train)
ridge_model = ridge.fit(X_train,y_train)
elasticnet_model = ENet.fit(X_train,y_train)
KRR_model = KRR.fit(X_train,y_train)
GBoost_model = GBoost.fit(X_train,y_train)
randomforest_model = rf.fit(X_train,y_train)
lr_model = lr.fit(X_train,y_train)
tree_model =tree.fit(X_train,y_train)

# %%
def blend_models(X):
    return (
        ((.1) * lasso_model.predict(X)) +
        ((.1) * ridge_model.predict(X)) +
        ((.1) * elasticnet_model.predict(X)) +
        ((.1) * KRR_model.predict(X)) +
        ((.6) * GBoost_model.predict(X))
           )

# %%
print(rmsle(y_train,blend_models(X_train)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-7c9f70d3709e> in <module>
# ----> 1 print(rmsle_cv(blend_models(X_train)))
#
# <ipython-input-2-94e0a7710466> in rmsle_cv(model)
#       4 def rmsle_cv(model):
#       5     kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
# ----> 6     rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
#       7     return(rmse)
#       8 def rmsle(y, y_pred):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     380     """
#     381     # To ensure multimetric format is not supported
# --> 382     scorer = check_scoring(estimator, scoring=scoring)
#     383
#     384     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\scorer.py in check_scoring(estimator, scoring, allow_none)
#     268     if not hasattr(estimator, 'fit'):
#     269         raise TypeError("estimator should be an estimator implementing "
# --> 270                         "'fit' method, %r was passed" % estimator)
#     271     if isinstance(scoring, str):
#     272         return get_scorer(scoring)
#
# TypeError: estimator should be an estimator implementing 'fit' method, array([12.21973264, 12.10087929, 12.27728748, ..., 12.44632196,
#        11.75670782, 11.90345719]) was passed

# %%
test['Prediction']=blend_models(test)

# %%
test.head()
# Out:
#    MSSubClass  OverallQual  OverallCond  YearBuilt  1stFlrSF  2ndFlrSF  \
# 0          20            5            6       1961       896         0
# 1          20            6            6       1958      1329         0
# 2          60            5            5       1997       928       701
# 3          60            6            6       1998       926       678
# 4         120            8            5       1992      1280         0
#
#    GrLivArea  FullBath  HalfBath  ScreenPorch  YrSold  Prediction
# 0        896         1         0          120    2010   11.751010
# 1       1329         1         1            0    2010   11.971719
# 2       1629         2         1            0    2010   12.072430
# 3       1604         2         1            0    2010   12.137646
# 4       1280         2         0          144    2010   12.184792

# %%
np.exp(test.Prediction)
# Out:
# 0       126881.676818
# 1       158216.420196
# 2       174980.476150
# 3       186772.458510
# 4       195788.889144
# 5       178669.375165
# 6       180321.732687
# 7       170334.042516
# 8       185377.503759
# 9       106170.549005
# 10      188966.440540
# 11      101138.415543
# 12       93963.002492
# 13      147568.199164
# 14      134854.428560
# 15      404318.535823
# 16      255809.178232
# 17      304439.019112
# 18      276283.238076
# 19      455533.731040
# 20      310616.835158
# 21      215406.958961
# 22      187967.324254
# 23      171619.059630
# 24      177966.753628
# 25      208560.037335
# 26      335328.104807
# 27      252375.741371
# 28      201521.047338
# 29      212503.822536
#             ...
# 1429     74467.715338
# 1430    146296.464327
# 1431     66432.203387
# 1432    132196.635184
# 1433     66406.083955
# 1434    280721.185950
# 1435    266235.330454
# 1436    200210.271205
# 1437    157003.568115
# 1438    241321.481308
# 1439    159785.291438
# 1440    194646.902691
# 1441    176710.853077
# 1442    334581.899323
# 1443    330046.021062
# 1444    119718.523646
# 1445    193228.323740
# 1446    122163.774604
# 1447    128457.925927
# 1448    148461.342827
# 1449     82840.551289
# 1450     88261.137769
# 1451    148006.990989
# 1452     84594.467677
# 1453     84594.467677
# 1454     92903.944444
# 1455     84594.467677
# 1456    145204.192592
# 1457    129618.679430
# 1458    227421.326996
# Name: Prediction, Length: 1459, dtype: float64

# %%
output=pd.DataFrame({
    'Id':np.arange(1461,2920),
    'SalePrice':np.exp(test.Prediction)
})

# %%
output.to_csv('house-prices-advanced-regression-techniques\\bt_prediction14.csv',index=False)
