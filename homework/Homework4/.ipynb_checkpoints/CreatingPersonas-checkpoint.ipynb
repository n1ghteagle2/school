# %% [markdown]
# ###Creating a persona profile using dendograms

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
import scipy.cluster.hierarchy as shc

# %%
df= pd.read_csv('Zeel_analytics_data.csv',skiprows=6)

# %%
df.head()
# Out:
#      Age                       Affinity Category (reach)  Gender      Region  \
# 0  25-34              Media & Entertainment/Movie Lovers  female  California
# 1  25-34              Media & Entertainment/Movie Lovers    male  California
# 2  25-34  Lifestyles & Hobbies/Art & Theater Aficionados  female  California
# 3  25-34                         Shoppers/Value Shoppers  female  California
# 4  25-34                             Travel/Travel Buffs  female  California
#
#   Device Category Sessions Avg. Session Duration  Pages / Session  \
# 0         desktop    1,775               0:04:27             6.16
# 1         desktop    1,642               0:03:07             5.91
# 2         desktop    1,599               0:04:44             6.19
# 3         desktop    1,569               0:04:23             6.16
# 4         desktop    1,551               0:04:26             6.23
#
#    All 5 Flow Conversions
# 0                      40
# 1                      29
# 2                      40
# 3                      40
# 4                      43

# %%
df.shape
# Out:
# (20000, 9)

# %%
#dummy variables
df=pd.get_dummies(df)

# %%
#check if anything is null
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
#load in X and y
X = df.loc[:, df.columns != 'All 5 Flow Conversions']
y = df['All 5 Flow Conversions']
X = pd.get_dummies(X)

# %%
#run random forest and fit
rf = RandomForestRegressor(n_estimators=100)

# %%
rf.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
#load in importance features using random forest
importances = pd.DataFrame({
    'Feature': X.columns,
    'Importance': np.round(rf.feature_importances_, 3)
}).sort_values(by='Importance', ascending=False)

# %%
importances
#Pages/Session
#Age_25-34
#Region - Cali/New York
#Age 35-44
#Region Texas
#Gender
#Device
# Out:
#                                                 Feature  Importance
# 0                                       Pages / Session       0.287
# 2                                             Age_25-34       0.083
# 128                                   Region_California       0.062
# 161                                     Region_New York       0.058
# 3                                             Age_35-44       0.027
# 175                                        Region_Texas       0.024
# 119                                         Gender_male       0.020
# 118                                       Gender_female       0.017
# 184                              Device Category_mobile       0.014
# 1                                             Age_18-24       0.008
# 183                             Device Category_desktop       0.006
# 4                                             Age_45-54       0.006
# 84    Affinity Category (reach)_Shoppers/Value Shoppers       0.005
# 22    Affinity Category (reach)_Lifestyles & Hobbies...       0.005
# 46    Affinity Category (reach)_Media & Entertainmen...       0.004
# 109       Affinity Category (reach)_Travel/Travel Buffs       0.004
# 970                       Avg. Session Duration_0:03:58       0.004
# 511                                         Sessions_36       0.004
# 107   Affinity Category (reach)_Technology/Technophiles       0.004
# 973                       Avg. Session Duration_0:04:01       0.004
# 981                       Avg. Session Duration_0:04:09       0.003
# 984                       Avg. Session Duration_0:04:12       0.003
# 5                                             Age_55-64       0.003
# 9     Affinity Category (reach)_Beauty & Wellness/Fr...       0.003
# 108   Affinity Category (reach)_Travel/Business Trav...       0.003
# 137                                      Region_Florida       0.003
# 17    Affinity Category (reach)_Food & Dining/Freque...       0.003
# 7     Affinity Category (reach)_Banking & Finance/Av...       0.003
# 158                                   Region_New Jersey       0.002
# 320                                        Sessions_181       0.002
# ...                                                 ...         ...
# 509                                        Sessions_358       0.000
# 508                                        Sessions_357       0.000
# 507                                        Sessions_356       0.000
# 504                                        Sessions_353       0.000
# 515                                        Sessions_363       0.000
# 503                                        Sessions_352       0.000
# 502                                        Sessions_351       0.000
# 501                                        Sessions_350       0.000
# 500                                         Sessions_35       0.000
# 499                                        Sessions_348       0.000
# 498                                        Sessions_347       0.000
# 514                                        Sessions_362       0.000
# 516                                        Sessions_364       0.000
# 534                                        Sessions_387       0.000
# 527                                        Sessions_380       0.000
# 533                                        Sessions_386       0.000
# 532                                        Sessions_385       0.000
# 531                                        Sessions_384       0.000
# 530                                        Sessions_383       0.000
# 529                                        Sessions_382       0.000
# 528                                        Sessions_381       0.000
# 526                                         Sessions_38       0.000
# 517                                        Sessions_365       0.000
# 525                                        Sessions_377       0.000
# 524                                        Sessions_375       0.000
# 523                                        Sessions_374       0.000
# 520                                        Sessions_368       0.000
# 519                                        Sessions_367       0.000
# 518                                        Sessions_366       0.000
# 1321                    Avg. Session Duration_<00:00:01       0.000
#
# [1322 rows x 2 columns]

# %%
# keep the top 25
vals_to_keep = importances['Feature'][:25].values.tolist()

# %%
# standardize data
data_for_cluster = (X[vals_to_keep] - X[vals_to_keep].mean()) / X[vals_to_keep].std()

# %%
# create the dendrogram
from scipy.cluster import hierarchy as hc
from scipy.stats import spearmanr as sp
import matplotlib.pyplot as plt
# %matplotlib inline

corr = np.round(sp(data_for_cluster).correlation, 4)
corr_condensed = hc.distance.squareform(1-corr)
z = hc.linkage(corr_condensed, method='average')
fig = plt.figure(figsize=(20,35))
dendrogram = hc.dendrogram(z, labels=vals_to_keep, orientation='left', leaf_font_size=14)
plt.show()

# %%
#Things that are linked:
#Device - Time using website - California - 18-24
#Female - Age 25-34 - Interest in Media/Entertainment - Shoppers
#Male - Texas - Age 55-64 and 45-54 - Banking - Finance

# %%
df2= pd.read_csv('Zeel_analytics_data2.csv',skiprows=6,usecols=[0,1,2,3,4,5,9],index_col='Index')

# %%
df2.head()
# Out:
#          Age                       Affinity Category (reach)  Gender  \
# Index
# 1      25-34              Media & Entertainment/Movie Lovers  female
# 2      25-34              Media & Entertainment/Movie Lovers    male
# 3      25-34  Lifestyles & Hobbies/Art & Theater Aficionados  female
# 4      25-34                         Shoppers/Value Shoppers  female
# 5      25-34                             Travel/Travel Buffs  female
#
#            Region Device Category  All 5 Flow Conversions
# Index
# 1      California         desktop                      40
# 2      California         desktop                      29
# 3      California         desktop                      40
# 4      California         desktop                      40
# 5      California         desktop                      43

# %%
#plt.figure(figsize=(10, 7))
#plt.scatter(df2[:-0], df2[:,1], c=cluster.labels_, cmap='rainbow')

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(df2['All 5 Flow Conversions'], df2['Age'], c=cluster.labels_)

# %%
#load in X and y
X2 = df2.loc[:, df2.columns != 'All 5 Flow Conversions']
y2 = df2['All 5 Flow Conversions']
X2 = pd.get_dummies(X2)

# %%
#run random forest and fit
rf2 = RandomForestRegressor(n_estimators=100)

# %%
rf2.fit(X2, y2)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
#load in importance features using random forest
importances2 = pd.DataFrame({
    'Feature': X2.columns,
    'Importance': np.round(rf2.feature_importances_, 3)
}).sort_values(by='Importance', ascending=False)

# %%
importances2
# Out:
#                                                Feature  Importance
# 1                                            Age_25-34       0.077
# 182                            Device Category_desktop       0.074
# 127                                  Region_California       0.062
# 118                                        Gender_male       0.049
# 117                                      Gender_female       0.048
# 2                                            Age_35-44       0.037
# 160                                    Region_New York       0.037
# 108      Affinity Category (reach)_Travel/Travel Buffs       0.028
# 45   Affinity Category (reach)_Media & Entertainmen...       0.026
# 83   Affinity Category (reach)_Shoppers/Value Shoppers       0.026
# 174                                       Region_Texas       0.021
# 21   Affinity Category (reach)_Lifestyles & Hobbies...       0.020
# 14     Affinity Category (reach)_Food & Dining/Foodies       0.019
# 106  Affinity Category (reach)_Technology/Technophiles       0.019
# 84   Affinity Category (reach)_Sports & Fitness/Hea...       0.019
# 20   Affinity Category (reach)_Lifestyles & Hobbies...       0.019
# 107  Affinity Category (reach)_Travel/Business Trav...       0.019
# 16   Affinity Category (reach)_Food & Dining/Freque...       0.019
# 9    Affinity Category (reach)_Food & Dining/Coffee...       0.019
# 8    Affinity Category (reach)_Beauty & Wellness/Fr...       0.019
# 82   Affinity Category (reach)_Shoppers/Shoppers by...       0.018
# 6    Affinity Category (reach)_Banking & Finance/Av...       0.017
# 24   Affinity Category (reach)_Lifestyles & Hobbies...       0.016
# 23   Affinity Category (reach)_Lifestyles & Hobbies...       0.016
# 53   Affinity Category (reach)_Media & Entertainmen...       0.012
# 3                                            Age_45-54       0.011
# 80      Affinity Category (reach)_Shoppers/Shopaholics       0.010
# 183                             Device Category_mobile       0.010
# 79   Affinity Category (reach)_Shoppers/Luxury Shop...       0.009
# 184                             Device Category_tablet       0.009
# ..                                                 ...         ...
# 98   Affinity Category (reach)_Sports & Fitness/Spo...       0.000
# 97   Affinity Category (reach)_Sports & Fitness/Spo...       0.000
# 96   Affinity Category (reach)_Sports & Fitness/Spo...       0.000
# 95   Affinity Category (reach)_Sports & Fitness/Spo...       0.000
# 94   Affinity Category (reach)_Sports & Fitness/Spo...       0.000
# 93   Affinity Category (reach)_Sports & Fitness/Spo...       0.000
# 36   Affinity Category (reach)_Media & Entertainmen...       0.000
# 40   Affinity Category (reach)_Media & Entertainmen...       0.000
# 49   Affinity Category (reach)_Media & Entertainmen...       0.000
# 139                                     Region_Gujarat       0.000
# 130                               Region_County Dublin       0.000
# 68   Affinity Category (reach)_Media & Entertainmen...       0.000
# 91   Affinity Category (reach)_Sports & Fitness/Spo...       0.000
# 70   Affinity Category (reach)_Media & Entertainmen...       0.000
# 135           Region_Federal Territory of Kuala Lumpur       0.000
# 134                                     Region_England       0.000
# 133                                       Region_Dubai       0.000
# 71   Affinity Category (reach)_Media & Entertainmen...       0.000
# 131                                       Region_Delhi       0.000
# 126                                  Region_Calabarzon       0.000
# 41   Affinity Category (reach)_Media & Entertainmen...       0.000
# 125                            Region_British Columbia       0.000
# 124                                     Region_Bangkok       0.000
# 123                                    Region_Auckland       0.000
# 43   Affinity Category (reach)_Media & Entertainmen...       0.000
# 121                                     Region_Alberta       0.000
# 120                                     Region_Alabama       0.000
# 119                                   Region_(not set)       0.000
# 42   Affinity Category (reach)_Media & Entertainmen...       0.000
# 92   Affinity Category (reach)_Sports & Fitness/Spo...       0.000
#
# [185 rows x 2 columns]

# %%
# keep the top 25
vals_to_keep2 = importances2['Feature'][:25].values.tolist()

# %%
# standardize data
data_for_cluster2 = (X2[vals_to_keep2] - X2[vals_to_keep2].mean()) / X2[vals_to_keep2].std()

# %%
# create the dendrogram
from scipy.cluster import hierarchy as hc
from scipy.stats import spearmanr as sp
import matplotlib.pyplot as plt
# %matplotlib inline

corr2 = np.round(sp(data_for_cluster2).correlation, 4)
corr_condensed2 = hc.distance.squareform(1-corr2)
z2 = hc.linkage(corr_condensed2, method='average')
fig = plt.figure(figsize=(20,35))
dendrogram = hc.dendrogram(z2, labels=vals_to_keep2, orientation='left', leaf_font_size=14)
plt.show()
